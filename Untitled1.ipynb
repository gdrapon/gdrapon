# %% [markdown]
# <a href="https://colab.research.google.com/github/gdrapon/gdrapon/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# GPUの確認
# !nvidia-smi
# Out:
# Tue Jan 24 06:45:01 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P0    26W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !git clone https://github.com/AUTOMATIC1111/stable-diffusion-webui
# %cd stable-diffusion-webui
# !wget https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt -O /content/stable-diffusion-webui/model.ckpt
# !wget https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0.vae.pt -O /content/stable-diffusion-webui/model.vae.pt
# Out:
# Cloning into 'stable-diffusion-webui'...
# remote: Enumerating objects: 15257, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 15257 (delta 0), reused 1 (delta 0), pack-reused 15253
# Receiving objects: 100% (15257/15257), 26.84 MiB | 12.33 MiB/s, done.
# Resolving deltas: 100% (10711/10711), done.
# /content/stable-diffusion-webui
# --2023-01-24 06:45:14--  https://huggingface.co/andite/anything-v4.0/resolve/main/anything-v4.0-pruned.ckpt
# Resolving huggingface.co (huggingface.co)... 54.235.118.239, 3.231.67.228, 2600:1f18:147f:e850:e203:c458:10cd:fc3c, ...
# Connecting to huggingface.co (huggingface.co)|54.235.118.239|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %%
# !COMMANDLINE_ARGS="--share --gradio-debug" REQS_FILE="requirements.txt" python launch.py
# Out:
# Python 3.8.10 (default, Nov 14 2022, 12:59:47)
# [GCC 9.4.0]
# Commit hash: 393e09c1c3217ad58a39c125fe2f46723a2fc11b
# Installing gfpgan
# Installing clip
# Installing open_clip
# Cloning Stable Diffusion into repositories/stable-diffusion-stability-ai...
# Cloning Taming Transformers into repositories/taming-transformers...
# Cloning K-diffusion into repositories/k-diffusion...
# Cloning CodeFormer into repositories/CodeFormer...
# Cloning BLIP into repositories/BLIP...
# Installing requirements for CodeFormer
# Installing requirements for Web UI
# Launching Web UI with arguments: --share --gradio-debug
# No module 'xformers'. Proceeding without it.
# LatentDiffusion: Running in eps-prediction mode
# DiffusionWrapper has 859.52 M params.
# Downloading: 100% 939k/939k [00:01<00:00, 726kB/s]
# Downloading: 100% 512k/512k [00:01<00:00, 472kB/s]
# Downloading: 100% 389/389 [00:00<00:00, 421kB/s]
# Downloading: 100% 905/905 [00:00<00:00, 954kB/s]
# ...
